# %%
import smart_shopper_assistant

# %%
from flask import Flask,request,jsonify

# %%
app=Flask(__name__)

@app.route('/run_lady',methods=['GET'])
def run_lady():
    data=request.json
    result=smart_shopper_assistant.run_lady()
    return result

@app.route('/greet',methods=['GET'])
def greet():
    data=request.json
    result=smart_shopper_assistant.greet()
    return result

@app.route('/speak_audio',methods=['POST'])                   
def speak(audio):
    data=request.json
    result=smart_shopper_assistant.speak(audio)
    return jsonify(result)

@app.route('/takeCommand',methods=['POST'])                   
def takeCommand():
    data=request.json
    result=smart_shopper_assistant.takeCommand()
    return jsonify(result)

@app.route('/username',methods=['GET'])                   
def username():
    data=request.json
    result=smart_shopper_assistant.username()
    return result



if __name__=='__main__':
    app.run()
# Out:
# Good evening,hope you had a good day.
# what should i call you?
# I am listening,please speak...
# result2:
# {   'alternative': [   {'confidence': 0.83222485, 'transcript': 'hello'},
#                        {'transcript': 'German hello'},
#                        {'transcript': 'tamia hello'},
#                        {'transcript': 'Jamia hello'},
#                        {'transcript': 'yeah hello'}],
#     'final': True}
# user: hello
# I am listening,please speak...
# Recognizing...
# result2:
# {   'alternative': [   {'confidence': 0.52093655, 'transcript': 'Beyoncé'},
#                        {'transcript': 'Beyonce'}],
#     'final': True}
# user: Beyoncé
# Hello Beyoncé
# welcome to Smart shopper,what would you like to shop for today?
# I am listening,please speak...
# Recognizing...
# result2:
# {   'alternative': [   {   'confidence': 0.89071721,
#                            'transcript': 'I would like to get a dress'},
#                        {'transcript': 'I would like to get address'}],
#     'final': True}
# user: I would like to get a dress
# Loading result
# I am listening,please speak...
# Recognizing...
# result2:
# []
#
# sorry,i did not get that...
# I am listening,please speak...
# Recognizing...
# Recognizing...
# result2:
# {   'alternative': [   {   'confidence': 0.88189566,
#                            'transcript': 'I would like to get a dress'},
#                        {'transcript': 'I would like to get address'}],
#     'final': True}
# user: I would like to get a dress
# Loading result
# I am listening,please speak...
# result2:
# {   'alternative': [   {   'confidence': 0.94461924,
#                            'transcript': 'I would like to buy a pen'},
#                        {'transcript': 'I would like to buy a Penn'},
#                        {'transcript': 'I would like to buy a penny'},
#                        {'transcript': 'I would like to buy a 10'},
#                        {'transcript': 'I would like to buy a pin'}],
#     'final': True}
# user: I would like to buy a pen
# Loading result
# I am listening,please speak...
# Recognizing...
# Recognizing...
# result2:
# {   'alternative': [   {'confidence': 0.26605648, 'transcript': 'bye'},
#                        {'transcript': 'by'},
#                        {'transcript': 'buy'},
#                        {'transcript': 'Bhai'},
#                        {'transcript': 'die'}],
#     'final': True}
# user: bye
# I am listening,please speak...
# result2:
# {   'alternative': [   {'confidence': 0.18206225, 'transcript': 'bye'},
#                        {'transcript': 'by'},
#                        {'transcript': 'die'},
#                        {'transcript': 'buy'},
#                        {'transcript': 'Guy'}],
#     'final': True}
# user: bye
# I am listening,please speak...
# Recognizing...
# result2:
# []
#
# sorry,i did not get that...
# I am listening,please speak...
# Recognizing...

# %% [markdown]
# import subprocess
# url='http://localhost:5000/run_lady'
# result=subprocess.run(['curl' ,url],capture_output=True, text=True)
#
# if result.returncode== 0:
#     print(result.stdout)
# else:
#     print(result.stderr)
